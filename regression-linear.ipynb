# %% [markdown]
# # Regression linear simple

# %%
# !pip3.11 install pandas numpy matplotlib scikit-learn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Estudio-Notas.csv')

plt.scatter(df['Horas Estudio'], df['Nota'])

# %%
df_median = df.median()
df_median
# Out:
# Horas Estudio    4.5
# Nota             9.0
# dtype: float64

# %%
# plot two dataframes
plt.scatter(df['Horas Estudio'], df['Nota'])
plt.scatter(df_median['Horas Estudio'], df_median['Nota'], color='red')

# %%
b1 = ((df['Horas Estudio'] - df['Horas Estudio'].mean()) * (df['Nota'] - df['Nota'].mean())).sum() / ((df['Horas Estudio'] - df['Horas Estudio'].mean())**2).sum()
b1
# Out:
# 1.223214285714286
