# %% [markdown]
# # Prototype v0.0.1

# %%
import os, sys
# Setup your root path
package_path = '/Users/miguel.romero/Workspace/miguelromero/machine-learning-the-ninja-path/prototypes/pimp-my-resume'
os.chdir(package_path)
if package_path not in sys.path:
  sys.path.append(package_path)
# !pip3 install -r ./libs/requirements.txt
# Out:
# zsh:1: /Users/miguel.romero/Workspace/miguelromero/machine-learning-the-ninja-path/.venv/bin/pip3: bad interpreter: /Users/miguel.romero/Workspace/ML-courses/.venv/bin/python3.11: no such file or directory
# Defaulting to user installation because normal site-packages is not writeable
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Collecting langchain
#   Downloading langchain-0.3.7-py3-none-any.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 1.1 MB/s eta 0:00:01
# Collecting langchain-openai
#   Downloading langchain_openai-0.2.6-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 6.8 MB/s  eta 0:00:01
# Collecting langchain_core
#   Downloading langchain_core-0.3.15-py3-none-any.whl (408 kB)
#      |████████████████████████████████| 408 kB 13.3 MB/s eta 0:00:01
# Collecting fastapi
#   Downloading fastapi-0.115.4-py3-none-any.whl (94 kB)
#      |████████████████████████████████| 94 kB 2.4 MB/s eta 0:00:01
# Collecting uvicorn
#   Downloading uvicorn-0.32.0-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 3.4 MB/s eta 0:00:01
# Collecting dependency-injector
#   Downloading dependency_injector-4.43.0-cp39-cp39-macosx_11_0_arm64.whl (722 kB)
#      |████████████████████████████████| 722 kB 24.0 MB/s eta 0:00:01
# Collecting StrEnum
#   Downloading StrEnum-0.4.15-py3-none-any.whl (8.9 kB)
# Collecting pydantic-settings
#   Downloading pydantic_settings-2.6.1-py3-none-any.whl (28 kB)
# Collecting pandas
#   Downloading pandas-2.2.3-cp39-cp39-macosx_11_0_arm64.whl (11.3 MB)
#      |████████████████████████████████| 11.3 MB 4.2 MB/s eta 0:00:01
# Collecting python-json-logger
#   Using cached python_json_logger-2.0.7-py3-none-any.whl (8.1 kB)
# Collecting requests
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 5.3 MB/s eta 0:00:01
# Collecting SQLAlchemy<3,>=1.4
#   Downloading SQLAlchemy-2.0.36-cp39-cp39-macosx_11_0_arm64.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 12.7 MB/s eta 0:00:01
# Collecting numpy<2,>=1
#   Downloading numpy-1.26.4-cp39-cp39-macosx_11_0_arm64.whl (14.0 MB)
#      |████████████████████████████████| 14.0 MB 10.0 MB/s eta 0:00:01
# Requirement already satisfied: PyYAML>=5.3 in /Users/miguel.romero/Library/Python/3.9/lib/python/site-packages (from langchain->-r ./libs/requirements.txt (line 2)) (6.0.1)
# Collecting async-timeout<5.0.0,>=4.0.0
#   Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Collecting pydantic<3.0.0,>=2.7.4
#   Downloading pydantic-2.9.2-py3-none-any.whl (434 kB)
#      |████████████████████████████████| 434 kB 10.8 MB/s eta 0:00:01
# Collecting aiohttp<4.0.0,>=3.8.3
#   Downloading aiohttp-3.10.10-cp39-cp39-macosx_11_0_arm64.whl (391 kB)
#      |████████████████████████████████| 391 kB 8.3 MB/s eta 0:00:01
# Collecting langsmith<0.2.0,>=0.1.17
#   Downloading langsmith-0.1.142-py3-none-any.whl (306 kB)
#      |████████████████████████████████| 306 kB 6.0 MB/s eta 0:00:01
# Collecting tenacity!=8.4.0,<10,>=8.1.0
#   Downloading tenacity-9.0.0-py3-none-any.whl (28 kB)
# Collecting langchain-text-splitters<0.4.0,>=0.3.0
#   Downloading langchain_text_splitters-0.3.2-py3-none-any.whl (25 kB)
# Collecting openai<2.0.0,>=1.54.0
#   Downloading openai-1.54.3-py3-none-any.whl (389 kB)
#      |████████████████████████████████| 389 kB 10.9 MB/s eta 0:00:01
# Collecting tiktoken<1,>=0.7
#   Downloading tiktoken-0.8.0-cp39-cp39-macosx_11_0_arm64.whl (983 kB)
#      |████████████████████████████████| 983 kB 7.4 MB/s eta 0:00:01
# Collecting jsonpatch<2.0,>=1.33
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Collecting typing-extensions>=4.7
#   Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/miguel.romero/Library/Python/3.9/lib/python/site-packages (from langchain_core->-r ./libs/requirements.txt (line 4)) (23.2)
# Collecting starlette<0.42.0,>=0.40.0
#   Downloading starlette-0.41.2-py3-none-any.whl (73 kB)
#      |████████████████████████████████| 73 kB 3.8 MB/s  eta 0:00:01
# Collecting h11>=0.8
#   Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Collecting click>=7.0
#   Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Requirement already satisfied: six<=1.16.0,>=1.7.0 in /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from dependency-injector->-r ./libs/requirements.txt (line 7)) (1.15.0)
# Collecting tzdata>=2022.7
#   Downloading tzdata-2024.2-py2.py3-none-any.whl (346 kB)
#      |████████████████████████████████| 346 kB 6.7 MB/s eta 0:00:01
# Collecting pytz>=2020.1
#   Downloading pytz-2024.2-py2.py3-none-any.whl (508 kB)
#      |████████████████████████████████| 508 kB 11.6 MB/s eta 0:00:01
# Collecting python-dateutil>=2.8.2
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
#      |████████████████████████████████| 229 kB 6.8 MB/s eta 0:00:01
# Collecting urllib3<3,>=1.21.1
#   Downloading urllib3-2.2.3-py3-none-any.whl (126 kB)
#      |████████████████████████████████| 126 kB 6.6 MB/s eta 0:00:01
# Collecting idna<4,>=2.5
#   Downloading idna-3.10-py3-none-any.whl (70 kB)
#      |████████████████████████████████| 70 kB 7.5 MB/s  eta 0:00:01
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/miguel.romero/Library/Python/3.9/lib/python/site-packages (from requests->-r ./libs/requirements.txt (line 12)) (3.3.2)
# Collecting certifi>=2017.4.17
#   Downloading certifi-2024.8.30-py3-none-any.whl (167 kB)
#      |████████████████████████████████| 167 kB 13.3 MB/s eta 0:00:01
# Collecting attrs>=17.3.0
#   Downloading attrs-24.2.0-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 3.0 MB/s  eta 0:00:01
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.1.0-cp39-cp39-macosx_11_0_arm64.whl (29 kB)
# Collecting aiosignal>=1.1.2
#   Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting yarl<2.0,>=1.12.0
#   Downloading yarl-1.17.1-cp39-cp39-macosx_11_0_arm64.whl (91 kB)
#      |████████████████████████████████| 91 kB 10.5 MB/s eta 0:00:01
# Collecting aiohappyeyeballs>=2.3.0
#   Downloading aiohappyeyeballs-2.4.3-py3-none-any.whl (14 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.5.0-cp39-cp39-macosx_11_0_arm64.whl (52 kB)
#      |████████████████████████████████| 52 kB 2.2 MB/s  eta 0:00:01
# Collecting jsonpointer>=1.9
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Collecting requests-toolbelt<2.0.0,>=1.0.0
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 5.5 MB/s  eta 0:00:01
# Collecting orjson<4.0.0,>=3.9.14
#   Downloading orjson-3.10.11-cp39-cp39-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl (266 kB)
#      |████████████████████████████████| 266 kB 12.6 MB/s eta 0:00:01
# Collecting httpx<1,>=0.23.0
#   Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#      |████████████████████████████████| 76 kB 6.4 MB/s eta 0:00:011
# Collecting anyio
#   Downloading anyio-4.6.2.post1-py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 4.0 MB/s eta 0:00:01
# Collecting httpcore==1.*
#   Downloading httpcore-1.0.6-py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 7.1 MB/s  eta 0:00:01
# Collecting sniffio
#   Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Collecting jiter<1,>=0.4.0
#   Downloading jiter-0.7.0-cp39-cp39-macosx_11_0_arm64.whl (291 kB)
#      |████████████████████████████████| 291 kB 11.0 MB/s eta 0:00:01
# Collecting tqdm>4
#   Downloading tqdm-4.67.0-py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 8.8 MB/s  eta 0:00:01
# Collecting distro<2,>=1.7.0
#   Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Collecting exceptiongroup>=1.0.2
#   Downloading exceptiongroup-1.2.2-py3-none-any.whl (16 kB)
# Collecting annotated-types>=0.6.0
#   Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Collecting pydantic-core==2.23.4
#   Downloading pydantic_core-2.23.4-cp39-cp39-macosx_11_0_arm64.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 15.5 MB/s eta 0:00:01
# Collecting regex>=2022.1.18
#   Downloading regex-2024.11.6-cp39-cp39-macosx_11_0_arm64.whl (284 kB)
#      |████████████████████████████████| 284 kB 11.7 MB/s eta 0:00:01
# Collecting propcache>=0.2.0
#   Downloading propcache-0.2.0-cp39-cp39-macosx_11_0_arm64.whl (46 kB)
#      |████████████████████████████████| 46 kB 5.0 MB/s  eta 0:00:01
# Installing collected packages: urllib3, typing-extensions, sniffio, idna, h11, exceptiongroup, certifi, requests, pydantic-core, httpcore, anyio, annotated-types, requests-toolbelt, pydantic, orjson, jsonpointer, httpx, tenacity, propcache, multidict, langsmith, jsonpatch, frozenlist, yarl, tqdm, regex, langchain-core, jiter, distro, attrs, async-timeout, aiosignal, aiohappyeyeballs, tzdata, tiktoken, starlette, SQLAlchemy, pytz, python-dotenv, python-dateutil, openai, numpy, langchain-text-splitters, click, aiohttp, uvicorn, StrEnum, python-json-logger, pydantic-settings, pandas, langchain-openai, langchain, fastapi, dependency-injector
#   WARNING: The script httpx is installed in '/Users/miguel.romero/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script langsmith is installed in '/Users/miguel.romero/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script tqdm is installed in '/Users/miguel.romero/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script distro is installed in '/Users/miguel.romero/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script dotenv is installed in '/Users/miguel.romero/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script openai is installed in '/Users/miguel.romero/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script f2py is installed in '/Users/miguel.romero/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script uvicorn is installed in '/Users/miguel.romero/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script langchain-server is installed in '/Users/miguel.romero/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script fastapi is installed in '/Users/miguel.romero/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed SQLAlchemy-2.0.36 StrEnum-0.4.15 aiohappyeyeballs-2.4.3 aiohttp-3.10.10 aiosignal-1.3.1 annotated-types-0.7.0 anyio-4.6.2.post1 async-timeout-4.0.3 attrs-24.2.0 certifi-2024.8.30 click-8.1.7 dependency-injector-4.43.0 distro-1.9.0 exceptiongroup-1.2.2 fastapi-0.115.4 frozenlist-1.5.0 h11-0.14.0 httpcore-1.0.6 httpx-0.27.2 idna-3.10 jiter-0.7.0 jsonpatch-1.33 jsonpointer-3.0.0 langchain-0.3.7 langchain-core-0.3.15 langchain-openai-0.2.6 langchain-text-splitters-0.3.2 langsmith-0.1.142 multidict-6.1.0 numpy-1.26.4 openai-1.54.3 orjson-3.10.11 pandas-2.2.3 propcache-0.2.0 pydantic-2.9.2 pydantic-core-2.23.4 pydantic-settings-2.6.1 python-dateutil-2.9.0.post0 python-dotenv-1.0.1 python-json-logger-2.0.7 pytz-2024.2 regex-2024.11.6 requests-2.32.3 requests-toolbelt-1.0.0 sniffio-1.3.1 starlette-0.41.2 tenacity-9.0.0 tiktoken-0.8.0 tqdm-4.67.0 typing-extensions-4.12.2 tzdata-2024.2 urllib3-2.2.3 uvicorn-0.32.0 yarl-1.17.1
# WARNING: You are using pip version 21.2.4; however, version 24.3.1 is available.
# You should consider upgrading via the '/Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip' command.

# %% [markdown]
# #### Load libraries and Setup env vars

# %%
import os
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
import utils.contstants as c
# from utils.prototype_v000 import PrototypeV000

load_dotenv()
OPEN_API_KEY = os.getenv("OPEN_API_KEY")

# %%
llm = ChatOpenAI(
  openai_api_key=OPEN_API_KEY,
  model_name="gpt-4o-mini",
  temperature=0)

# %%
from langchain_core.globals import set_debug
set_debug(True)

# %%
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_template(c.PROMPT_TEMPLATE)

document_chain = create_stuff_documents_chain(llm, prompt)

# %%
from langchain_core.documents import Document

document_chain.invoke({
    "answer": "Solid es un acronimo de los 5 principios de diseño de software orientado a objetos, que se utilizan para desarrollar software que sea más fácil de mantener y extender a lo largo del tiempo. Los principios son: Single Responsibility Principle, Open/Closed Principle, Liskov Substitution Principle, Interface Segregation Principle, Dependency Inversion Principle.",
    "context": [Document(page_content=CONTEXT, page_title="S.O.L.I.D. Principles")],
    "categories": CATEGORIES
})
