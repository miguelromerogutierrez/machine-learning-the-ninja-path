# %% [markdown]
# # Docline PoC
#
# The goal of this experiment is determine if docline has the features to make easier to fetch information from multiple sources.

# %%
# %pip install docling docling-core
# Out:
# ...
#
# [notice] A new release of pip is available: 23.3.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from docling.document_converter import DocumentConverter

source = "https://medium.com/@miguel.angel.romero.gtz/apuntes-de-javascript-validaciones-2473dac172aa"
converter = DocumentConverter()
result = converter.convert(source)

# %%
print(result.document.export_to_markdown())
# print(result.document.export_to_document_tokens())
# print(result.document.export_to_dict())
# Out:
# Sign up
#
# Sign in
#
# Sign up
#
# Sign in
#
# <!-- image -->
#
# # Apuntes de Javascript: validaciones
#
# <!-- image -->
#
# Mike Romero
#
# Follow
#
# --
#
# Share
#
# <!-- image -->
#
# En estos días estuve lidiando con formularios en react, y como siempre, quise implementar buenos patrones y hacerme la vida más fácil en el futuro. Como no era la primera vez que realizaba esto ya tenía un método preparado, este consistía en ir generando pequeñas validaciones para saber los tipos de errores que el usuario tenía al escribir sobre un campo. Por ejemplo, el campo de número telefónico tenemos que validar la longitud y que sean soló números, luego si el usuario no respeta alguna de estas reglas habrá que presentarle un mensaje de error correspondiente a la regla incumplida. Así haciendo pequeñas validaciones sobre cada regla incumplida podia saber que mensaje de error le mostraría al usuario.
#
# ...
